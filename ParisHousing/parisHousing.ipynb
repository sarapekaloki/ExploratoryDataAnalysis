# %% [markdown]
# # Paris Housing exploratory data analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
paris_housing = pd.read_csv("ParisHousing.csv")
paris_housing
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %% [markdown]
# ### Descriptive Statistics

# %%
#General Statistics
paris_housing.describe().round()
# Out:
#        squareMeters  numberOfRooms  hasYard  hasPool   floors  cityCode  \
# count       10000.0        10000.0  10000.0  10000.0  10000.0   10000.0
# mean        49870.0           50.0      1.0      0.0     50.0   50225.0
# std         28774.0           29.0      0.0      1.0     29.0   29007.0
# min            89.0            1.0      0.0      0.0      1.0       3.0
# 25%         25098.0           25.0      0.0      0.0     25.0   24694.0
# 50%         50106.0           50.0      1.0      0.0     50.0   50693.0
# 75%         74610.0           75.0      1.0      1.0     76.0   75683.0
# max         99999.0          100.0      1.0      1.0    100.0   99953.0
#
#        cityPartRange  numPrevOwners     made  isNewBuilt  hasStormProtector  \
# count        10000.0        10000.0  10000.0     10000.0            10000.0
# mean             6.0            6.0   2005.0         0.0                0.0
# std              3.0            3.0      9.0         1.0                1.0
# ...

# %%
#Distribution of square meters
#The standard deviation and the mean for this value are really high, abnormal size of a property in such a big city
plt.figure(figsize=(8, 6))
sns.histplot(paris_housing['squareMeters'], kde=True)


# add labels and title
plt.xlabel('Square meters')
plt.ylabel('Frequency')
plt.title('Distribution of square meters of property')
plt.show()

# %%
#Correlation between price and square meters
paris_housing.plot(x="squareMeters", y="price", style="o")
